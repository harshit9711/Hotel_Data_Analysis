# %% [markdown]
# ## Hotel Data Analysis

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Exploration

# %%
df_bookings = pd.read_csv("fact_bookings.csv")
df_agg_bookings = pd.read_csv("fact_aggregated_bookings.csv")
df_hotels = pd.read_csv("dim_hotels.csv")
df_rooms = pd.read_csv("dim_rooms.csv")
df_date = pd.read_csv("dim_date.csv")

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_rooms.shape
# Out:
# (4, 2)

# %%
df_date.shape
# Out:
# (92, 4)

# %%
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_rooms.head(3)
# Out:
#   room_id room_class
# 0     RT1   Standard
# 1     RT2      Elite
# 2     RT3    Premium

# %%
df_rooms.room_class.unique()
# Out:
# array(['Standard', 'Elite', 'Premium', 'Presidential'], dtype=object)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: booking_platform, dtype: int64

# %%
df_rooms.room_class.value_counts()
# Out:
# Standard        1
# Elite           1
# Premium         1
# Presidential    1
# Name: room_class, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot()
# Out:
# <Axes: >

# %%
df_bookings.booking_platform.value_counts().plot(kind = "barh")
# Out:
# <Axes: >

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_agg_bookings.describe()
# Out:
#         property_id  successful_bookings     capacity
# count   9200.000000          9200.000000  9198.000000
# mean   18040.640000            14.655761    25.280496
# std     1099.818325             7.736170    11.442080
# min    16558.000000             1.000000     3.000000
# 25%    17558.000000             9.000000    18.000000
# 50%    17564.000000            14.000000    25.000000
# 75%    18563.000000            19.000000    34.000000
# max    19563.000000           123.000000    50.000000

# %%
df_hotels.describe()
# Out:
#         property_id
# count     25.000000
# mean   18040.640000
# std     1122.436371
# min    16558.000000
# 25%    17558.000000
# 50%    17564.000000
# 75%    18563.000000
# max    19563.000000

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %% [markdown]
# # Data Cleaning

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# 17924       14-05-22      -10.0           RT4    direct online            NaN
# 18020       14-05-22      -12.0           RT2     makeyourtrip            NaN
# 18119       17-05-22       -6.0           RT3   direct offline            5.0
# 18121       17-05-22       -4.0           RT3    direct online            NaN
# 56715       13-06-22      -17.0           RT1           others            NaN
# 119765      22-07-22       -1.0           RT2           others            NaN
# 134586      1/8/2022       -4.0           RT4          logtrip            2.0
#
#        booking_status  revenue_generated  revenue_realized
# 0         Checked Out              10010             10010
# 3           Cancelled               9100              3640
# 17924         No Show              20900             20900
# 18020       Cancelled               9000              3600
# 18119     Checked Out              16800             16800
# 18121       Cancelled              14400              5760
# 56715     Checked Out               6500              6500
# 119765    Checked Out              13500             13500
# 134586    Checked Out              38760             38760

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings=df_bookings[df_bookings.no_guests>0]

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max(),
# Out:
# (6500, 28560000)

# %%
avg , std = df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std(),

# %%
avg , std
# Out:
# (15378.036937686695, 93040.15493143328)

# %%
higher_limit=avg + 3*std
higher_limit
# Out:
# 294498.50173198653

# %%
lower_limit= avg - 3*std

# %%
lower_limit
# Out:
# -263742.4278566132

# %%
df_bookings[df_bookings.revenue_generated<0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings.revenue_generated>=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 4           2/5/2022        4.0           RT1    direct online            5.0
# 5           3/5/2022        2.0           RT1           others            4.0
# 6           6/5/2022        2.0           RT1           others            NaN
# ...              ...        ...           ...              ...            ...
# 134584      1/8/2022        2.0           RT4           others            2.0
# 134585      3/8/2022        1.0           RT4     makeyourtrip            2.0
# 134587      2/8/2022        1.0           RT4         tripster            NaN
# 134588      1/8/2022        2.0           RT4          logtrip            2.0
# 134589      1/8/2022        2.0           RT4     makeyourtrip            NaN
#
#        booking_status  revenue_generated  revenue_realized
# 1           Cancelled               9100              3640
# 2         Checked Out            9100000              9100
# 4         Checked Out              10920             10920
# 5         Checked Out               9100              9100
# 6           Cancelled               9100              3640
# ...               ...                ...               ...
# 134584    Checked Out              32300             32300
# 134585    Checked Out              32300             32300
# 134587      Cancelled              32300             12920
# 134588    Checked Out              32300             32300
# 134589      Cancelled              32300             12920
#
# [134578 rows x 12 columns]

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# 2         Checked Out            9100000              9100
# 111       Checked Out           28560000             28560
# 315       Checked Out           12600000             12600
# 562         Cancelled            2000000              4420
# 129176    Checked Out           10000000             12600

# %%
df_bookings = df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings.shape
# Out:
# (134573, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit= df_bookings.revenue_realized.mean() + 3*df_bookings.revenue_realized.std()
higher_limit
# Out:
# 33479.3586618449

# %% [markdown]
# # Data Transformation

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings["occ pct"] = df_agg_bookings["occ pct"].apply(lambda x: round(x*100,2))

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ pct
# 0     83.0
# 1     93.0
# 2     77.0
# 3    158.0
# 4     95.0

# %% [markdown]
# # Insights Generation

# %% [markdown]
# # 1. What is an average occupancy rate in each of the room categories?

# %%
df_agg_bookings.groupby("room_category")["occ pct"].mean().round(2)
# Out:
# room_category
# RT1    58.24
# RT2    58.04
# RT3    58.01
# RT4    59.30
# Name: occ pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_agg_bookings,df_rooms,left_on="room_category" , right_on="room_id")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ pct room_id room_class
# 0     83.0     RT1   Standard
# 1     93.0     RT1   Standard
# 2     77.0     RT1   Standard
# 3    158.0     RT1   Standard
# 4     95.0     RT1   Standard

# %%
df.groupby("room_class")["occ pct"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.01
# Presidential    59.30
# Standard        58.24
# Name: occ pct, dtype: float64

# %%
df.drop("room_class",axis=1,inplace=True)
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ pct room_id
# 0     83.0     RT1
# 1     93.0     RT1
# 2     77.0     RT1
# 3    158.0     RT1

# %% [markdown]
# # 2. Print average occupancy rate per city

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ pct
# 0     83.0
# 1     93.0
# 2     77.0
# 3    158.0
# 4     95.0

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df = pd.merge(df,df_hotels, on="property_id")
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
#
#    occ pct room_id property_name_x category_x  city_x property_name_y  \
# 0     83.0     RT1   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 1     67.0     RT1   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 2     57.0     RT1   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
#
#   category_y  city_y  property_name category    city
# 0     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 1     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 2     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai

# %%
df.groupby("city")["occ pct"].mean().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# # 3. When was the occupancy better? Weekday or Weekend?

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
#
#    occ pct room_id property_name_x category_x  city_x property_name_y  \
# 0     83.0     RT1   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 1     67.0     RT1   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 2     57.0     RT1   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
#
#   category_y  city_y  property_name category    city
# 0     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 1     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 2     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai

# %%
df = pd.merge(df,df_date,left_on="check_in_date" , right_on="date")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
# 3        16559     10-May-22           RT4                   13      18.0
# 4        19562     10-May-22           RT1                   18      30.0
#
#    occ pct room_id property_name_x category_x     city_x property_name_y  \
# 0     60.0     RT1   Atliq Exotica     Luxury     Mumbai   Atliq Exotica
# 1     61.0     RT2   Atliq Exotica     Luxury     Mumbai   Atliq Exotica
# 2     62.0     RT3   Atliq Exotica     Luxury     Mumbai   Atliq Exotica
# 3     72.0     RT4   Atliq Exotica     Luxury     Mumbai   Atliq Exotica
# 4     60.0     RT1       Atliq Bay     Luxury  Bangalore       Atliq Bay
#
#   category_y     city_y  property_name category       city       date  mmm yy  \
# 0     Luxury     Mumbai  Atliq Exotica   Luxury     Mumbai  10-May-22  May 22
# 1     Luxury     Mumbai  Atliq Exotica   Luxury     Mumbai  10-May-22  May 22
# 2     Luxury     Mumbai  Atliq Exotica   Luxury     Mumbai  10-May-22  May 22
# 3     Luxury     Mumbai  Atliq Exotica   Luxury     Mumbai  10-May-22  May 22
# 4     Luxury  Bangalore      Atliq Bay   Luxury  Bangalore  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday
# 2    W 20  weekeday
# 3    W 20  weekeday
# 4    W 20  weekeday

# %%
df.groupby("day_type")["occ pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.41
# Name: occ pct, dtype: float64

# %% [markdown]
# # 4. In the month of June, what is the occupancy for different cities

# %%
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june_22 = df[df["mmm yy"]=="Jun 22"]
df_june_22.head(3)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        16559     10-Jun-22           RT2                   26      41.0
# 2202        16559     10-Jun-22           RT3                   20      32.0
#
#       occ pct room_id property_name_x category_x  city_x property_name_y  \
# 2200     67.0     RT1   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 2201     63.0     RT2   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 2202     62.0     RT3   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
#
#      category_y  city_y  property_name category    city       date  mmm yy  \
# 2200     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai  10-Jun-22  Jun 22
# 2201     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai  10-Jun-22  Jun 22
# 2202     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai  10-Jun-22  Jun 22
#
#      week no  day_type
# 2200    W 24  weekeday
# 2201    W 24  weekeday
# 2202    W 24  weekeday

# %%
df_june_22.groupby("city")["occ pct"].mean().round(2)
# Out:
# city
# Bangalore    56.58
# Delhi        62.49
# Hyderabad    58.47
# Mumbai       58.39
# Name: occ pct, dtype: float64

# %% [markdown]
# # 5. Add the august data to the existing records

# %%
df_august = pd.read_csv("new_data_august.csv")
df_august.head(3)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67

# %%
latest_df = pd.concat([df,df_august], ignore_index=True, axis=0)
latest_df.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        18560     31-Jul-22           RT2                   34      40.0
# 6498        18560     31-Jul-22           RT3                   17      24.0
# 6499        18560     31-Jul-22           RT4                   12      15.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ pct room_id property_name_x category_x     city_x  ...     city_y  \
# 6497     85.0     RT2      Atliq City   Business  Hyderabad  ...  Hyderabad
# 6498     71.0     RT3      Atliq City   Business  Hyderabad  ...  Hyderabad
# 6499     80.0     RT4      Atliq City   Business  Hyderabad  ...  Hyderabad
# 6500      NaN     NaN             NaN        NaN        NaN  ...        NaN
# 6501      NaN     NaN             NaN        NaN        NaN  ...        NaN
# 6502      NaN     NaN             NaN        NaN        NaN  ...        NaN
# 6503      NaN     NaN             NaN        NaN        NaN  ...        NaN
# 6504      NaN     NaN             NaN        NaN        NaN  ...        NaN
# 6505      NaN     NaN             NaN        NaN        NaN  ...        NaN
# 6506      NaN     NaN             NaN        NaN        NaN  ...        NaN
#
#       property_name  category       city       date  mmm yy week no  day_type  \
# 6497     Atliq City  Business  Hyderabad  31-Jul-22  Jul 22    W 32   weekend
# 6498     Atliq City  Business  Hyderabad  31-Jul-22  Jul 22    W 32   weekend
# 6499     Atliq City  Business  Hyderabad  31-Jul-22  Jul 22    W 32   weekend
# 6500  Atliq Exotica    Luxury     Mumbai        NaN  Aug-22    W 32  weekeday
# 6501      Atliq Bay    Luxury  Bangalore        NaN  Aug-22    W 32  weekeday
# 6502   Atliq Palace  Business  Bangalore        NaN  Aug-22    W 32  weekeday
# 6503   Atliq Grands    Luxury  Bangalore        NaN  Aug-22    W 32  weekeday
# 6504     Atliq City  Business  Bangalore        NaN  Aug-22    W 32  weekeday
# 6505      Atliq Blu    Luxury     Mumbai        NaN  Aug-22    W 32  weekeday
# 6506  Atliq Seasons  Business     Mumbai        NaN  Aug-22    W 32  weekeday
#
#      room_class    occ%
# 6497        NaN     NaN
# 6498        NaN     NaN
# 6499        NaN     NaN
# 6500   Standard  100.00
# 6501   Standard   70.00
# 6502   Standard   76.67
# 6503   Standard   75.00
# 6504   Standard   76.92
# 6505   Standard   69.23
# 6506   Standard   62.50
#
# [10 rows x 22 columns]

# %% [markdown]
# # 6. Print revenue realized per city

# %%
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920
# 5               9100              9100
# 6               9100              3640

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_bookings_all=pd.merge(df_bookings,df_hotels,on="property_id")
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %% [markdown]
# # 7. Print month by month revenue

# %%
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
df_date["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
pd.merge(df_bookings_all,df_date,left_on="check_in_date",right_on="date")
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
df_date["date"]= pd.to_datetime(df_date["date"])
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_bookings_all["check_in_date"]= pd.to_datetime(df_bookings_all["check_in_date"])
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(9)
# memory usage: 16.4+ MB

# %%
df_bookings_all = pd.merge(df_bookings_all,df_date,left_on="check_in_date",right_on="date")
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
#
#    ...  week no_x  day_type_x     date_y mmm yy_y week no_y day_type_y  \
# 0  ...       W 19    weekeday 2022-05-05   May 22      W 19   weekeday
# 1  ...       W 19    weekeday 2022-05-05   May 22      W 19   weekeday
# 2  ...       W 19    weekeday 2022-05-05   May 22      W 19   weekeday
#
#         date  mmm yy week no  day_type
# 0 2022-05-05  May 22    W 19  weekeday
# 1 2022-05-05  May 22    W 19  weekeday
# 2 2022-05-05  May 22    W 19  weekeday
#
# [3 rows x 27 columns]

# %%
df_bookings_all.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    389940912
# Jun 22    377191229
# May 22    408375641
# Name: revenue_realized, dtype: int64
